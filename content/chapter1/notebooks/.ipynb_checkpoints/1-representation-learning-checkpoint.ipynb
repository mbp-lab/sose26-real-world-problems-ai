# %% [markdown]
# In the last notebook, you explored the curse of dimensionality. Here, you will work with real, high-dimensional data in a small sample.

# %% [markdown]
# Station 1: Representation learning lite
#
# In this station, we will use a multi-class regression model to differentiate between ... text dataset that has news entries (text) from five different categories (). You will notice that the dataset is already divided into train and validation split (80:20). This is done for didactic purposes to keep things comparable.
#
# As the original data is text, our first job is to turn it into numerical representations. To save you the trouble, the representations are already computed and available as files. These representations are bag-of-words and tf-idf. They were computed using Python's CountVectorizer() and TfidfVectorizer(). Read about how they work.
#
# Load the datasets ... and. ... and check out the dataset structure and columns.
#
# We will consider three common methods in natural language processing: bag-of-words, tf-idf and embeddings. Python has the functions. Use them to get the representations. How many dimensions do you end up with with each method?
#
# Now, before moving to the ML training, let's take the chance to also try 3 visulization methods. Use PCA, t-sne and UMAP to project your data into lower dimensions. What do you notice?
